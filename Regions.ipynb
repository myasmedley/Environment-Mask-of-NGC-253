# %% [markdown]
# # Trying to get the size of ngc 253 lol

# %%
from regions import Regions

# %%
ha_disk_region = Regions.read('OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/DS9 NGC 253 Updated Region Files/Disk/disk_ha_regionfile_adjusted71026_muse', format='ds9')

# %%
print(ha_disk_region) #this displays the ra, dec, width in arcsec, and height in arcsec
# Out:
# <EllipseSkyRegion(center=<SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (11.8592577, -25.3126187)>, width=1558.382 arcsec, height=305.59 arcsec, angle=321.0021 deg)>
