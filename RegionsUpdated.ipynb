# %% [markdown]
# # Regions in NGC 253: Plotting Regions on DS9-defined Structures

# %% [markdown]
# ### Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import astropy.units as u
import os
import shutil
from astropy.io import fits # importing fits 
from astropy.utils.data import download_file # simple method of downloading FITS file 
from astropy.visualization import astropy_mpl_style # resource for organized plots
from astropy.visualization import ZScaleInterval, MinMaxInterval, AsinhStretch, LogStretch, ImageNormalize # quality image display/visualization
from astropy.wcs import WCS #coordinate conversion
from regions import Regions # import astropy region class

# %% [markdown]
# ## A.) Class to Display FITS Image Data and Plot DS9 Regions

# %%
class DisplayData: 
    """" A class to open FITS file, display image data, 
         and plot a DS9.reg file onto the image data. """ 
    def __init__(self, filepath):
        """ Initialize through opening the data.""" 
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul: # opening file
            data = None
            header = None
            for hdu in hdul: #loops through each extension (HDU) in the list of HDUs to check if data has dimensions (thanks rav!)
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
       # hdu = fits.open(filepath)[1] #okay index 1 isn't always gong to work. you need to write an if statement to test 0


    def display_header(self, filepath):
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")

    def display_image(self, filepath, norm, vmin, vmax):
        self.filepath = filepath 
        self.norm = norm #fitting certain function/curve to bring out details in an image 
        self.vmin = vmin #darkness control
        self.vmax = vmax #brightness control
        #hdu = fits.open(filepath)[1]
        #data = hdu.data
        #header = hdu.header 
        from astropy.io import fits
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")



        plt.figure(figsize=(8, 8))
        plt.imshow(data, cmap="gray", origin="lower", norm=self.norm, vmin=self.vmin, vmax=self.vmax) #figure out a way to add normalization parameter into this function
        plt.colorbar(label="Intensity", fraction=0.0146, aspect=20)
        plt.show()

    
    def plot_region(self, filepath, regionfile, norm, vmin, vmax):
        self.filepath = filepath
        self.regionfile = regionfile # DS9 region
        self.norm = norm 
        self.vmin = vmin
        self.vmax= vmax
        
        from astropy.io import fits 
        from astropy.wcs import WCS
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
            
        wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
        region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel
        fig, ax = plt.subplots() 
        ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
        region.plot(ax=ax, color='red', lw=2.0)

# %% [markdown]
# ## A-Part 1: Image Display

# %% [markdown]
# ### CO emission: ACA 7m

# %%
co_hdu = fits.open(r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_7m+tp_co21_mom0.fits")[0]
co_data = co_hdu.data 
co_header = co_hdu.header
co_data2D = co_data[0]
print(co_data2D.shape)
# Out:
# (493, 565)

# %%
norm = ImageNormalize(co_data2D, 
                         interval=ZScaleInterval(), # changing the scale to zscale and stretching to show emission (works like ds9 settings?)
                          stretch=AsinhStretch())

plt.figure(figsize=(8, 8))
plt.imshow(co_data2D, cmap='gray', origin="lower", norm=norm)
plt.colorbar(label="Intensity", fraction=0.0146, aspect=20)
plt.title("NGC 253 - CO, 7m ACA")
plt.show()

# %%
co_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_7m+tp_co21_mom0.fits"
co_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ngc0253_7m+tp_co21_mom0.fits"
co_data2D.plot_region(co_file, co_disk_regionfile, norm, None, None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 3
#       1 co_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_7m+tp_co21_mom0.fits"
#       2 co_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ngc0253_7m+tp_co21_mom0.fits"
# ----> 3 co_data2D.plot_region(co_file, co_disk_regionfile, norm, None, None)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot_region'

# %% [markdown]
# ### 21 CM: HI

# %%
h1_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_21cm_strictmask_mom0.fits"
h1_data = DisplayData(h1_file)
h1_data.display_image(h1_file, 'linear', None, None)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY

# %%
h1_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/NGC0253_21cm_strictmask_mom0.fits"
h1_data.plot_region(h1_file, h1_disk_regionfile, 'linear', vmin=None, vmax=None)
# Out:
# Found data in extension: PRIMARY
# ---------------------------------------------------------------------------
# FITSParserError                           Traceback (most recent call last)
# Cell In[79], line 2
#       1 h1_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/NGC0253_21cm_strictmask_mom0.fits"
# ----> 2 h1_data.plot_region(h1_file, h1_disk_regionfile, 'linear', vmin=None, vmax=None)
#
# Cell In[73], line 92, in DisplayData.plot_region(self, filepath, regionfile, norm, vmin, vmax)
#      88         if data is None:
#      89             print("None")
#      90
#      91         wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
# ---> 92         region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel
#      93         fig, ax = plt.subplots()
#      94         ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
#      95         region.plot(ax=ax, color='red', lw=2.0)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\core\regions.py:179, in Regions.read(cls, filename, format, cache, **kwargs)
#     140 @classmethod
#     141 def read(cls, filename, format=None, cache=False, **kwargs):
#     142     """
#     143     Read and parse a region file and return as a Regions object.
#     144
#    (...)    177         A `~regions.Regions` object containing the file contents.
#     178     """
# --> 179     return RegionsRegistry.read(filename, cls, format=format,
#     180                                 cache=cache, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\core\registry.py:100, in RegionsRegistry.read(cls, filename, classobj, format, **kwargs)
#      95     msg = (f'No reader defined for format "{format}" and class '
#      96            f'"{classobj.__name__}".\n'
#      97            f'{cls._get_format_table_str(classobj)}')
#      98     raise IORegistryError(msg) from None
# --> 100 return reader(filename, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\io\fits\read.py:68, in _read_fits(filename, cache)
#      65         regions = _parse_fits(region_table)
#      66         return regions
# ---> 68 raise FITSParserError('An extension with name (EXTNAME) "REGION" '
#      69                       'was not found')
#
# FITSParserError: An extension with name (EXTNAME) "REGION" was not found

# %% [markdown]
# ### H-alpha: MUSE

# %%
ha_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_Ha.fits"
ha_data = DisplayData(ha_file)
ha_data.display_image(ha_file, 'log', 30, 30000)
# Out:
# Found data in extension: HA6562_FLUX
# Found data in extension: HA6562_FLUX

# %%
ha_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\disk_ha_regionfile_adjusted71026_muse.reg"
ha_data.plot_region(ha_file, ha_disk_regionfile)
# Out:
# Found data in extension: HA6562_FLUX

# %% [markdown]
# ### IRAC4: Spitzer

# %%
irac4_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_irac4_gauss4p0.fits"
irac4_data = DisplayData(irac4_file)
irac4_data.display_image(irac4_file, 'asinh', None, None)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY

# %%
irac4_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_irac_regionfile_adjusted71326_spitzer.reg"
irac4_data.plot_region(irac4_file, irac4_disk_regionfile, 'asinh', None, None)
# Out:
# Found data in extension: PRIMARY

# %% [markdown]
# ### MIRI f21: JWST

# %%
mirif21_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_miri_lv3_f2100w_i2d_align.fits"
mirif21_data = DisplayData(mirif21_file)
mirif21_data.display_image(mirif21_file, 'asinh', None, None)
# Out:
# Found data in extension: SCI
# Found data in extension: SCI

# %%
mirif21_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_mirif21_regionfile_jwst_adjusted713026.reg"
mirif21_data.plot_region(mirif21_file, mirif21_disk_regionfile, 'asinh', None, None)
# Out:
# Found data in extension: SCI
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-11-04T13:42:03.937' from MJD-BEG.
# Set DATE-AVG to '2023-11-04T21:47:11.691' from MJD-AVG.
# Set DATE-END to '2023-11-05T05:40:24.115' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    69.442647 from OBSGEO-[XYZ].
# Set OBSGEO-B to    25.154213 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1482168350.904 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %% [markdown]
# ### R-band: WFI

# %%
rband_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_Rc_flux_wcomb.fits"
rband_data = DisplayData(rband_file)
rband_data.display_image(rband_file, norm='asinh', vmin=None, vmax=None)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY

# %%
rband_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_rbandrcflux_regionfile_wfi.reg"
rband_data.plot_region(rband_file, rband_disk_regionfile, 'asinh', None, None)
# Out:
# Found data in extension: PRIMARY
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 rband_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_rbandrcflux_regionfile_wfi.reg"
# ----> 2 rband_data.plot_region(rband_file, rband_disk_regionfile, 'asinh', None, None)
#
# Cell In[81], line 92, in DisplayData.plot_region(self, filepath, regionfile, norm, vmin, vmax)
#      88         if data is None:
#      89             print("None")
#      90
#      91         wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
# ---> 92         region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel
#      93         fig, ax = plt.subplots()
#      94         ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
#      95         region.plot(ax=ax, color='red', lw=2.0)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\core\regions.py:37, in Regions.__getitem__(self, index)
#      36 def __getitem__(self, index):
# ---> 37     newregions = self.regions[index]
#      38     if isinstance(newregions, Region):  # one item
#      39         return newregions
#
# IndexError: list index out of range

# %% [markdown]
# ### UVIS f814: HST

# %%
uvis_file= r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc253_uvis_f814w_exp_drc_sci.fits"
uvis_data = DisplayData(uvis_file)
uvis_data.display_image(uvis_file, norm='log', vmin=30, vmax=30000)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\backend_bases.py:2249, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2246     # we do this instead of `self.figure.draw_without_rendering`
#    2247     # so that we can inject the orientation
#    2248     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2249         self.figure.draw(renderer)
#    2250 else:
#    2251     renderer = None
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_base.py:3350, in _AxesBase.draw(self, renderer)
#    3347 if artists_rasterized:
#    3348     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3350 mimage._draw_list_compositing_images(
#    3351     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3353 renderer.close_group('axes')
#    3354 self.stale = False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:633, in _ImageBase.draw(self, renderer)
#     631         renderer.draw_image(gc, l, b, im, trans)
#     632 else:
# --> 633     im, l, b, trans = self.make_image(
#     634         renderer, renderer.get_image_magnification())
#     635     if im is not None:
#     636         renderer.draw_image(gc, l, b, im)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:936, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     933 transformed_bbox = TransformedBbox(bbox, trans)
#     934 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     935         else self.get_figure(root=True).bbox)
# --> 936 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     937                         magnification, unsampled=unsampled)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\image.py:516, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     514 if A.ndim == 2:  # interpolation_stage = 'rgba'
#     515     self.norm.autoscale_None(A)
# --> 516     A = self.to_rgba(A)
#     517 if A.dtype == np.uint8:
#     518     # uint8 is too imprecise for premultiplied alpha roundtrips.
#     519     A = np.divide(A, 0xff, dtype=np.float32)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colorizer.py:358, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     328 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     329     """
#     330     Return a normalized RGBA array corresponding to *x*.
#     331
#    (...)    356
#     357     """
# --> 358     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colorizer.py:146, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     144 if norm:
#     145     x = self.norm(x)
# --> 146 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     147 return rgba
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colors.py:779, in Colormap.__call__(self, X, alpha, bytes)
#     756 def __call__(self, X, alpha=None, bytes=False):
#     757     r"""
#     758     Parameters
#     759     ----------
#    (...)    777     RGBA values with a shape of ``X.shape + (4, )``.
#     778     """
# --> 779     rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     780     if not np.iterable(X):
#     781         rgba = tuple(rgba)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colors.py:836, in Colormap._get_rgba_and_mask(self, X, alpha, bytes)
#     833 if bytes:
#     834     lut = (lut * 255).astype(np.uint8)
# --> 836 rgba = lut.take(xa, axis=0, mode='clip')
#     838 if alpha is not None:
#     839     alpha = np.clip(alpha, 0, 1)
#
# MemoryError: Unable to allocate 7.54 GiB for an array with shape (9502, 26627, 4) and data type float64

# %% [markdown]
# ### V-band: MUSE

# %%
vband_file= r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_V.fits"
vband_data = DisplayData(vband_file)
vband_data.display_image(vband_file, norm='log', 30, 30000)

# %% [markdown]
# ### W1: WISE

# %%
w1_file= r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_w1_bgsub.fits"
w1_data = DisplayData(w1_file)
w1_data.display_image(w1_file, norm='log', 30, 30000)
