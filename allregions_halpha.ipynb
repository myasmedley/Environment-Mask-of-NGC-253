# %% [markdown]
# # Plotting All Regions on H-alpha

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import astropy.units as u
import os
import shutil
from astropy.io import fits # importing fits 
from astropy.utils.data import download_file # simple method of downloading FITS file 
from astropy.visualization import astropy_mpl_style # resource for organized plots
from astropy.visualization import ZScaleInterval, MinMaxInterval, AsinhStretch, LogStretch, ImageNormalize # quality image display/visualization
from astropy.wcs import WCS #coordinate conversion
from regions import Regions # import astropy region class

# %%
class DisplayData: 
    """" A class to open FITS file, display image data, 
         and plot a DS9.reg file onto the image data. """ 
    def __init__(self, filepath):
        """ Initialize through opening the data.""" 
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul: # opening file
            data = None
            header = None
            for hdu in hdul: #loops through each extension (HDU) in the list of HDUs to check if data has dimensions (thanks rav!)
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
       # hdu = fits.open(filepath)[1] #okay index 1 isn't always gong to work. you need to write an if statement to test 0


    def display_header(self, filepath):
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    display(header)
                    break 
            
        if data is None:
            print("None")

    def display_image(self, filepath, norm, vmin, vmax):
        self.filepath = filepath 
        self.norm = norm
        self.vmin = vmin
        self.vmax = vmax
        #brightness control
        #hdu = fits.open(filepath)[1]
        #data = hdu.data
        #header = hdu.header 
        from astropy.io import fits
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")



        plt.figure(figsize=(8, 8))
        plt.imshow(data, cmap="gray", origin="lower", norm=self.norm, vmin=self.vmin, vmax=self.vmax) #figure out a way to add normalization parameter into this function
        plt.colorbar(label="Intensity", fraction=0.0146, aspect=20)

      
            
    
    def plot_region(self, filepath, 
                    disk1_regionfile, disk2_regionfile,
                    disk3_regionfile, disk4_regionfile, disk5_regionfile, disk6_regionfile, 
                    disk7_regionfile, disk8_regionfile, disk9_regionfile, disk10_regionfile,
                    
                    ring1_regionfile, ring2_regionfile, ring3_regionfile, ring4_regionfile,
                    ring5_regionfile, ring6_regionfile, ring7_regionfile, ring8_regionfile,
                    ring9_regionfile, ring10_regionfile,
                   
                    bar1_regionfile, bar2_regionfile, bar3_regionfile, bar4_regionfile,
                    bar5_regionfile, bar6_regionfile, bar7_regionfile,

                    center1_regionfile, center2_regionfile, center3_regionfile, center4_regionfile,
                    center5_regionfile, center6_regionfile, center7_regionfile, center8_regionfile,
                    

                    spiralarms1_regionfile, spiralarms2_regionfile, spiralarms3_regionfile, spiralarms4_regionfile,
                    spiralarms5_regionfile, spiralarms6_regionfile, spiralarms7_regionfile, spiralarms8_regionfile,
                    spiralarms9_regionfile, spiralarms10_regionfile, 

                    norm, vmin, vmax, figname): 
        
        self.filepath = filepath
      
        self.disk1_regionfile = disk1_regionfile
        self.disk2_regionfile = disk2_regionfile
        self.disk3_regionfile = disk3_regionfile
        self.disk4_regionfile = disk4_regionfile
        self.disk5_regionfile = disk5_regionfile 
        self.disk6_regionfile = disk6_regionfile 
        self.disk7_regionfile = disk7_regionfile
        self.disk8_regionfile = disk8_regionfile
        self.disk9_regionfile = disk9_regionfile
        self.disk10_regionfile = disk10_regionfile


        
        self.ring1_regionfile = ring1_regionfile
        self.ring2_regionfile = ring2_regionfile
        self.ring3_regionfile = ring3_regionfile
        self.ring4_regionfile = ring4_regionfile
        self.ring5_regionfile = ring5_regionfile
        self.ring6_regionfile = ring6_regionfile
        self.ring7_regionfile = ring7_regionfile
        self.ring8_regionfile = ring8_regionfile
        self.ring9_regionfile = ring9_regionfile
        self.ring10_regionfile = ring10_regionfile


        self.bar1_regionfile = bar1_regionfile
        self.bar2_regionfile = bar2_regionfile
        self.bar3_regionfile = bar3_regionfile
        self.bar4_regionfile = bar4_regionfile
        self.bar5_regionfile = bar5_regionfile
        self.bar6_regionfile = bar6_regionfile
        self.bar7_regionfile = bar7_regionfile


        self.center1_regionfile = center1_regionfile
        self.center2_regionfile = center2_regionfile
        self.center3_regionfile = center3_regionfile
        self.center4_regionfile = center4_regionfile
        self.center5_regionfile = center5_regionfile
        self.center6_regionfile = center6_regionfile
        self.center7_regionfile = center7_regionfile
        self.center8_regionfile = center8_regionfile

        
        self.spiralarms1_regionfile = spiralarms1_regionfile
        self.spiralarms2_regionfile = spiralarms2_regionfile
        self.spiralarms3_regionfile = spiralarms3_regionfile
        self.spiralarms4_regionfile = spiralarms4_regionfile
        self.spiralarms5_regionfile = spiralarms5_regionfile
        self.spiralarms6_regionfile = spiralarms6_regionfile
        self.spiralarms7_regionfile = spiralarms7_regionfile
        self.spiralarms8_regionfile = spiralarms8_regionfile
        self.spiralarms9_regionfile = spiralarms9_regionfile
        self.spiralarms10_regionfile = spiralarms10_regionfile

        

        self.norm = norm 
        self.vmin = vmin
        self.vmax= vmax 
        self.figname = figname
        from astropy.io import fits 
        from astropy.wcs import WCS
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
            
        wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
        # access region file via parsing & converting data from wcs to pixel. the 0 is for the FIRST region plotted
        # for i in regionfile??? what i want to do is for each region in the regionfile, plot each region if an index exists for that region

        disk_region1 = Regions.read(disk1_regionfile)[0].to_pixel(wcs)
        disk_region2 = Regions.read(disk2_regionfile)[0].to_pixel(wcs) # access region file via , # the one corresponds to
        disk_region3 = Regions.read(disk3_regionfile)[0].to_pixel(wcs) 
        disk_region4 = Regions.read(disk4_regionfile)[0].to_pixel(wcs)
        disk_region5 = Regions.read(disk5_regionfile)[0].to_pixel(wcs)
        disk_region6 = Regions.read(disk6_regionfile)[0].to_pixel(wcs)
        disk_region7 = Regions.read(disk7_regionfile)[0].to_pixel(wcs)
        disk_region8 = Regions.read(disk8_regionfile)[0].to_pixel(wcs)
        disk_region9 = Regions.read(disk9_regionfile)[0].to_pixel(wcs)
        disk_region10 = Regions.read(disk10_regionfile)[0].to_pixel(wcs)
        

        ring_region1 = Regions.read(ring1_regionfile)[0].to_pixel(wcs)
        ring_region11 = Regions.read(ring1_regionfile)[1].to_pixel(wcs)
        ring_region2 = Regions.read(ring2_regionfile)[0].to_pixel(wcs)
        ring_region22 = Regions.read(ring2_regionfile)[1].to_pixel(wcs)
        ring_region3 = Regions.read(ring3_regionfile)[0].to_pixel(wcs)
        ring_region33 = Regions.read(ring3_regionfile)[1].to_pixel(wcs)
        ring_region4 = Regions.read(ring4_regionfile)[0].to_pixel(wcs)
        ring_region44 = Regions.read(ring4_regionfile)[1].to_pixel(wcs)
        ring_region5 = Regions.read(ring5_regionfile)[0].to_pixel(wcs)
        ring_region55 = Regions.read(ring5_regionfile)[1].to_pixel(wcs)
        ring_region6 = Regions.read(ring6_regionfile)[0].to_pixel(wcs)
        ring_region66 = Regions.read(ring6_regionfile)[1].to_pixel(wcs)
        ring_region7 = Regions.read(ring7_regionfile)[0].to_pixel(wcs)
        ring_region77 = Regions.read(ring7_regionfile)[1].to_pixel(wcs)
        ring_region8 = Regions.read(ring8_regionfile)[0].to_pixel(wcs)
        ring_region88 = Regions.read(ring8_regionfile)[1].to_pixel(wcs)
        ring_region9 = Regions.read(ring9_regionfile)[0].to_pixel(wcs)
        ring_region99 = Regions.read(ring9_regionfile)[1].to_pixel(wcs)
        ring_region10 = Regions.read(ring10_regionfile)[0].to_pixel(wcs)
        ring_region100 = Regions.read(ring10_regionfile)[1].to_pixel(wcs)


        bar_region1 = Regions.read(bar1_regionfile)[0].to_pixel(wcs)
        bar_region11 = Regions.read(bar1_regionfile)[1].to_pixel(wcs)
        bar_region2 = Regions.read(bar2_regionfile)[0].to_pixel(wcs)
        bar_region22 = Regions.read(bar2_regionfile)[1].to_pixel(wcs)
        bar_region3 = Regions.read(bar3_regionfile)[0].to_pixel(wcs)
        bar_region33 = Regions.read(bar3_regionfile)[1].to_pixel(wcs)
        bar_region4 = Regions.read(bar4_regionfile)[0].to_pixel(wcs)
        bar_region44 = Regions.read(bar4_regionfile)[1].to_pixel(wcs)
        bar_region5 = Regions.read(bar5_regionfile)[0].to_pixel(wcs)
        bar_region55 = Regions.read(bar5_regionfile)[1].to_pixel(wcs)
        bar_region6 = Regions.read(bar6_regionfile)[0].to_pixel(wcs)
        bar_region66 = Regions.read(bar6_regionfile)[1].to_pixel(wcs)
        bar_region7 = Regions.read(bar7_regionfile)[0].to_pixel(wcs)
        bar_region77 = Regions.read(bar7_regionfile)[1].to_pixel(wcs)

        center_region1 = Regions.read(center1_regionfile)[0].to_pixel(wcs)
        center_region2 = Regions.read(center2_regionfile)[0].to_pixel(wcs) 
        center_region3 = Regions.read(center3_regionfile)[0].to_pixel(wcs) 
        center_region4 = Regions.read(center4_regionfile)[0].to_pixel(wcs)
        center_region5 = Regions.read(center5_regionfile)[0].to_pixel(wcs)
        center_region6 = Regions.read(center6_regionfile)[0].to_pixel(wcs)
        center_region7 = Regions.read(center7_regionfile)[0].to_pixel(wcs)
        center_region8 = Regions.read(center8_regionfile)[0].to_pixel(wcs)
    

        spiralarms_region1 = Regions.read(spiralarms1_regionfile)[0].to_pixel(wcs)  
        spiralarms_region11 = Regions.read(spiralarms1_regionfile)[1].to_pixel(wcs)
        spiralarms_region2 = Regions.read(spiralarms2_regionfile)[0].to_pixel(wcs)
        spiralarms_region22 = Regions.read(spiralarms2_regionfile)[1].to_pixel(wcs)
        spiralarms_region3 = Regions.read(spiralarms3_regionfile)[0].to_pixel(wcs)
        spiralarms_region33 = Regions.read(spiralarms3_regionfile)[1].to_pixel(wcs)
        spiralarms_region4 = Regions.read(spiralarms4_regionfile)[0].to_pixel(wcs)
        spiralarms_region44 = Regions.read(spiralarms4_regionfile)[1].to_pixel(wcs)
        spiralarms_region5 = Regions.read(spiralarms5_regionfile)[0].to_pixel(wcs)
        spiralarms_region55 = Regions.read(spiralarms5_regionfile)[1].to_pixel(wcs)
        spiralarms_region6 = Regions.read(spiralarms6_regionfile)[0].to_pixel(wcs)
        spiralarms_region66 = Regions.read(spiralarms6_regionfile)[1].to_pixel(wcs)
        spiralarms_region7 = Regions.read(spiralarms7_regionfile)[0].to_pixel(wcs)
        spiralarms_region77 = Regions.read(spiralarms7_regionfile)[1].to_pixel(wcs)
        spiralarms_region8 = Regions.read(spiralarms8_regionfile)[0].to_pixel(wcs)
        spiralarms_region88 = Regions.read(spiralarms8_regionfile)[1].to_pixel(wcs)
        spiralarms_region9 = Regions.read(spiralarms9_regionfile)[0].to_pixel(wcs)
        spiralarms_region99 = Regions.read(spiralarms9_regionfile)[1].to_pixel(wcs)
        spiralarms_region10 = Regions.read(spiralarms10_regionfile)[0].to_pixel(wcs)
        spiralarms_region100 = Regions.read(spiralarms10_regionfile)[1].to_pixel(wcs)
        
        fig, ax = plt.subplots(subplot_kw=dict(projection=wcs))
        red_patch = mpatches.Patch(color='red', label='CO') #https://matplotlib.org/stable/users/explain/axes/legend_guide.html
        orange_patch = mpatches.Patch(color='orange', label='H1')
        yellow_patch = mpatches.Patch(color='yellow', label='H-alpha')
        green_patch = mpatches.Patch(color='green', label='IRAC4')
        blue_patch = mpatches.Patch(color='blue', label='IRAC1')
        purple_patch = mpatches.Patch(color='purple', label='mirif21')
        pink_patch = mpatches.Patch(color='pink', label='r-band')
        turquoise_patch = mpatches.Patch(color='turquoise', label='UVIS')
        royalblue_patch = mpatches.Patch(color='royalblue', label='v-band')
        grey_patch = mpatches.Patch(color='grey', label='W1')
        
        
        ax.legend(handles=[red_patch, orange_patch, yellow_patch, green_patch, blue_patch, purple_patch, pink_patch, turquoise_patch, royalblue_patch, grey_patch])
        ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax) 
         #https://docs.astropy.org/en/stable/visualization/wcsaxes/index.html
    
        
        overlay = ax.get_coords_overlay('fk5')
        overlay[0].set_axislabel('Right Ascension (J2000)')
        overlay[1].set_axislabel('Declination (J2000)')
        
        disk_region1.plot(ax=ax, color='red', lw=2.0) #co
        disk_region2.plot(ax=ax, color='orange', lw=2.0) #h1
        disk_region3.plot(ax=ax, color= 'yellow', lw=2.0) #halpha
        disk_region4.plot(ax=ax, color='green', lw=2.0) #irac4
        disk_region5.plot(ax=ax, color='blue', lw=2.0) #irac1
        disk_region6.plot(ax=ax, color= 'purple', lw=2.0) #miri
        disk_region7.plot(ax=ax, color='pink', lw=2.0) #rband
        disk_region8.plot(ax=ax, color='turquoise', lw=2.0) #uvis
        disk_region9.plot(ax=ax, color= 'royalblue', lw=2.0) #vband
        disk_region10.plot(ax=ax, color='grey', lw=2.0) #w1
        
        
        
        ring_region1.plot(ax=ax, color='red', lw=2.0)
        ring_region11.plot(ax=ax, color='red', lw=2.0)
        ring_region2.plot(ax=ax, color= 'orange', lw=1.0)
        ring_region22.plot(ax=ax, color= 'orange', lw=1.0)
        ring_region3.plot(ax=ax, color= 'yellow', lw=1.0)
        ring_region33.plot(ax=ax, color= 'yellow', lw=1.0)
        ring_region4.plot(ax=ax, color='green', lw=2.0)
        ring_region44.plot(ax=ax, color='green', lw=2.0)
        ring_region5.plot(ax=ax, color= 'blue', lw=1.0)
        ring_region55.plot(ax=ax, color= 'blue', lw=1.0)
        ring_region6.plot(ax=ax, color= 'purple', lw=1.0)
        ring_region66.plot(ax=ax, color= 'purple', lw=1.0)
        ring_region7.plot(ax=ax, color='pink', lw=2.0)
        ring_region77.plot(ax=ax, color='pink', lw=2.0)
        ring_region8.plot(ax=ax, color= 'turquoise', lw=1.0)
        ring_region88.plot(ax=ax, color= 'turquoise', lw=1.0)
        ring_region9.plot(ax=ax, color= 'royalblue', lw=1.0)
        ring_region99.plot(ax=ax, color= 'royalblue', lw=1.0)
        ring_region10.plot(ax=ax, color= 'grey', lw=1.0)
        ring_region100.plot(ax=ax, color= 'grey', lw=1.0)

        bar_region1.plot(ax=ax, color='red', lw=2.0)
        bar_region11.plot(ax=ax, color='red', lw=2.0)
        bar_region2.plot(ax=ax, color= 'orange', lw=1.0)
        bar_region22.plot(ax=ax, color= 'orange', lw=1.0)
        bar_region3.plot(ax=ax, color= 'yellow', lw=1.0)
        bar_region33.plot(ax=ax, color= 'yellow', lw=1.0)
        bar_region4.plot(ax=ax, color='green', lw=2.0)
        bar_region44.plot(ax=ax, color='green', lw=2.0)
        bar_region5.plot(ax=ax, color= 'blue', lw=1.0)
        bar_region55.plot(ax=ax, color= 'blue', lw=1.0)
        bar_region6.plot(ax=ax, color= 'purple', lw=1.0) 
        bar_region66.plot(ax=ax, color= 'purple', lw=1.0)
        bar_region7.plot(ax=ax, color='grey', lw=2.0)
        bar_region77.plot(ax=ax, color='grey', lw=2.0)

        center_region1.plot(ax=ax, color='red', lw=2.0) #co
        center_region2.plot(ax=ax, color= 'yellow', lw=2.0) #halpha
        center_region3.plot(ax=ax, color='green', lw=2.0) #irac4
        center_region4.plot(ax=ax, color='blue', lw=2.0) #irac1
        center_region5.plot(ax=ax, color='pink', lw=2.0) #rband
        center_region6.plot(ax=ax, color='turquoise', lw=2.0) #uvis
        center_region7.plot(ax=ax, color= 'royalblue', lw=2.0) #vband
        center_region8.plot(ax=ax, color='grey', lw=2.0) #w1

        
        spiralarms_region1.plot(ax=ax, color='red', lw=2.0)
        spiralarms_region11.plot(ax=ax, color='red', lw=2.0)
        spiralarms_region2.plot(ax=ax, color= 'orange', lw=1.0)
        spiralarms_region22.plot(ax=ax, color= 'orange', lw=1.0)
        spiralarms_region3.plot(ax=ax, color= 'yellow', lw=1.0)
        spiralarms_region33.plot(ax=ax, color= 'yellow', lw=1.0)
        spiralarms_region4.plot(ax=ax, color='green', lw=2.0)
        spiralarms_region44.plot(ax=ax, color='green', lw=2.0)
        spiralarms_region5.plot(ax=ax, color= 'blue', lw=1.0)
        spiralarms_region55.plot(ax=ax, color= 'blue', lw=1.0)
        spiralarms_region6.plot(ax=ax, color= 'purple', lw=1.0)
        spiralarms_region66.plot(ax=ax, color= 'purple', lw=1.0)
        spiralarms_region7.plot(ax=ax, color='pink', lw=2.0)
        spiralarms_region77.plot(ax=ax, color='pink', lw=2.0)
        spiralarms_region8.plot(ax=ax, color= 'turquoise', lw=1.0)
        spiralarms_region88.plot(ax=ax, color= 'turquoise', lw=1.0)
        spiralarms_region9.plot(ax=ax, color= 'royalblue', lw=1.0)
        spiralarms_region99.plot(ax=ax, color= 'royalblue', lw=1.0)
        spiralarms_region10.plot(ax=ax, color= 'grey', lw=1.0)
        spiralarms_region100.plot(ax=ax, color= 'grey', lw=1.0)
            
        
        
        plt.savefig(figname, bbox_inches ='tight') #https://stackoverflow.com/questions/9651092/my-matplotlib-pyplot-legend-is-being-cut-off

# %%
# %matplotlib widget
ha_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_Ha.fits"
ha_data = DisplayData(ha_file)

co_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_co_regionfile_aca.reg"
h1_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_H1_regionfile_meerkatradio.reg"
ha_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_ha_regionfile_adjusted71626_muse.reg"
irac4_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_irac_regionfile_adjusted71326_spitzer.reg"
irac1_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_irac1_regionfile_spitzer.reg"
mirif21_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_mirif21_regionfile_jwst_adjusted713026.reg"
rband_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\DS9 NGC 253 Updated Region Files\Disk\disk_rbandrcflux_regionfile_wfi.reg"
uvis_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_uvis_regionfile_hst.reg"
vband_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/disk_vband_regionfile_muse.reg"
w1_disk_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\DS9 NGC 253 Updated Region Files\Disk\disk_w1_regionfile_wise.reg"


co_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_co_regionfile_aca_thicker.reg"
h1_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_H1_regionfile_meerkatradio.reg"
ha_ring_regionfile =  r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_ha_regionfile_muse_2.reg"
irac4_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_irac_regionfile_spitzer.reg"
irac1_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_irac1_regionfile_spitzer.reg"
mirif21_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_mirif21_regionfile_jwst_thicker.reg"
rband_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_rband_regionfile2_wfi.reg"
uvis_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_uvis_regionfile_hst_bottomclosertocenter.reg"
vband_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_vband_regionfile_muse.reg"
w1_ring_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ring_w1_regionfile_wise.reg"

co_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_co_regionfile_aca_twoboxes.reg"
h1_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_H1_regionfile_meerkatradio.reg"
ha_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_ha_regionfile_muse_twoboxes.reg"
irac4_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_irac4_regionfile_spitzer_twoboxes.reg"
irac1_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_irac1_regionfile_spitzer.reg"
mirif21_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_f21miri_regionfile_jwst_twoboxes_updated.reg"
w1_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_w1_regionfile_wise_twoboxes.reg"

co_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_co_regionfile_aca.reg"
ha_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_ha_regionfile_muse.reg"
irac4_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_irac4_regionfile_spitzer.reg"
irac1_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_irac1_regionfile_spitzer.reg"
rband_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_rband_regionfile_wfi.reg"
uvis_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_uvis_regionfile_hst.reg"
vband_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_vband_regionfile_muse.reg"
w1_center_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/center_w1_regionfile_wise1.reg"


co_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_co_regionfile_aca.reg"
h1_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_h1_regionfile_meerkat.reg"
ha_spiralarms_regionfile =  r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_ha_regionfile_muse.reg"
irac4_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_irac4_regionfile_spitzer.reg"
irac1_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_irac1_regionfile_spitzer.reg"
mirif21_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_mirif21_regionfile_jwst.reg"
rband_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_rband_regionfile_wfi.reg"
uvis_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_uvis_regionfile_hst.reg"
vband_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_vband_regionfile_muse.reg"
w1_spiralarms_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/spiralarms_w1_regionfile_wise.reg"





ha_data.plot_region(ha_file, 
                    
                    co_disk_regionfile, h1_disk_regionfile,
                    ha_disk_regionfile, irac4_disk_regionfile, irac1_disk_regionfile, mirif21_disk_regionfile, 
                    rband_disk_regionfile, uvis_disk_regionfile, vband_disk_regionfile, w1_disk_regionfile,
                   
                    co_ring_regionfile, h1_ring_regionfile, ha_ring_regionfile, irac4_ring_regionfile,
                    irac1_ring_regionfile, mirif21_ring_regionfile, rband_ring_regionfile, uvis_ring_regionfile,
                    vband_ring_regionfile, w1_ring_regionfile, 
                    
                    co_bar_regionfile, h1_bar_regionfile, ha_bar_regionfile, irac4_bar_regionfile,
                    irac1_bar_regionfile, mirif21_bar_regionfile, w1_bar_regionfile, 
                    
                    co_center_regionfile, ha_center_regionfile, irac4_center_regionfile, irac1_center_regionfile,
                    rband_center_regionfile, uvis_center_regionfile, vband_center_regionfile, w1_center_regionfile, 
                    
                    co_spiralarms_regionfile, h1_spiralarms_regionfile, ha_spiralarms_regionfile, irac4_spiralarms_regionfile,
                    irac1_spiralarms_regionfile, mirif21_spiralarms_regionfile, rband_spiralarms_regionfile, uvis_spiralarms_regionfile,
                    vband_spiralarms_regionfile, w1_spiralarms_regionfile, 

                    norm = 'log', vmin=30, vmax=30000, figname='all regions h-alpha')
# Out:
# Found data in extension: HA6562_FLUX
# Found data in extension: HA6562_FLUX
# C:\Users\Lamat\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\ellipse.py:222: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Ellipse(xy=xy, width=width, height=height, angle=angle,
# C:\Users\Lamat\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\rectangle.py:219: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Rectangle(xy=xy, width=width, height=height,
# C:\Users\Lamat\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\polygon.py:225: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Polygon(xy=xy, **mpl_kwargs)
