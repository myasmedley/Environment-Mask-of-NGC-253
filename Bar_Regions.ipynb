# %% [markdown]
# ## Plotting Regions on NGC 253: Bar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import astropy.units as u
import os
import shutil
from astropy.io import fits # importing fits 
from astropy.utils.data import download_file # simple method of downloading FITS file 
from astropy.visualization import astropy_mpl_style # resource for organized plots
from astropy.visualization import ZScaleInterval, MinMaxInterval, AsinhStretch, LogStretch, ImageNormalize # quality image display/visualization
from astropy.wcs import WCS #coordinate conversion
from regions import Regions # import astropy region class

# %%
class DisplayData: 
    """" A class to open FITS file, display image data, 
         and plot a DS9.reg file onto the image data. """ 
    def __init__(self, filepath):
        """ Initialize through opening the data.""" 
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul: # opening file
            data = None
            header = None
            for hdu in hdul: #loops through each extension (HDU) in the list of HDUs to check if data has dimensions (thanks rav!)
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
       # hdu = fits.open(filepath)[1] #okay index 1 isn't always gong to work. you need to write an if statement to test 0


    def display_header(self, filepath):
        self.filepath = filepath
        from astropy.io import fits 
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")

    def display_image(self, filepath, norm, vmin, vmax):
        self.filepath = filepath 
        self.norm = norm
        self.vmin = vmin
        self.vmax = vmax
        #brightness control
        #hdu = fits.open(filepath)[1]
        #data = hdu.data
        #header = hdu.header 
        from astropy.io import fits
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")



        plt.figure(figsize=(8, 8))
        plt.imshow(data, cmap="gray", origin="lower", norm=self.norm, vmin=self.vmin, vmax=self.vmax) #figure out a way to add normalization parameter into this function
        plt.colorbar(label="Intensity", fraction=0.0146, aspect=20)
    

    
    def plot_region(self, filepath, regionfile, norm, vmin, vmax):
        self.filepath = filepath
        self.regionfile = regionfile # DS9 region
        self.norm = norm 
        self.vmin = vmin
        self.vmax= vmax 
        from astropy.io import fits 
        from astropy.wcs import WCS
        with fits.open(filepath) as hdul:
            data = None
            header = None
            for hdu in hdul:
                if hdu.data is not None and hdu.header.get("NAXIS",0) >= 2:
                    data = hdu.data 
                    header = hdu.header 
                    print(f"Found data in extension: {hdu.name or hdul.index(hdu)}")
                    break 
            
        if data is None:
            print("None")
            
        wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
        region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel. the 0 is for the FIRST region plotted 
        region2 = Regions.read(regionfile)[1].to_pixel(wcs) # the one corresponds to the SECOND region plotted 
        fig, ax = plt.subplots() 
        ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
        region.plot(ax=ax, color='orange', lw=1.0)
        region2.plot(ax=ax, color='orange', lw=1.0)

# %% [markdown]
# ## CO: ACA

# %%
co_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_7m+tp_co21_mom0.fits"
co_data = DisplayData(co_file)
co_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_co_regionfile_aca_twoboxes.reg"
co_data.plot_region(co_file, co_bar_regionfile, norm='linear', vmin=0.00003, vmax=300)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\core.py:635, in TimeBase._get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, mask)
#     634         val, val2 = cls._fill_masked_values(oval, oval2, mask, in_subfmt)
# --> 635     return cls(val, val2, scale, precision, in_subfmt, out_subfmt)
#     636 except UnitConversionError:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\formats.py:171, in TimeFormat.__init__(self, val1, val2, scale, precision, in_subfmt, out_subfmt, from_jd)
#     170 else:
# --> 171     val1, val2 = self._check_val_type(val1, val2)
#     172     self.set_jds(val1, val2)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\formats.py:534, in TimeNumeric._check_val_type(self, val1, val2)
#     533 if val1.dtype.kind == "f":
# --> 534     val1, val2 = super()._check_val_type(val1, val2)
#     535 elif not orig_val2_is_none or not (
#     536     val1.dtype.kind in "US"
#     537     or (
#    (...)    540     )
#     541 ):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\formats.py:324, in TimeFormat._check_val_type(self, val1, val2)
#     323 if self.__class__._check_finite:
# --> 324     self._check_finite_vals(val1, val2)
#     326 if getattr(val1, "unit", None) is not None:
#     327     # Convert any quantity-likes to days first, attempting to be
#     328     # careful with the conversion, so that, e.g., large numbers of
#     329     # seconds get converted without losing precision because
#     330     # 1/86400 is not exactly representable as a float.
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\formats.py:317, in TimeFormat._check_finite_vals(self, val1, val2)
#     316 if not (ok1 and ok2):
# --> 317     raise TypeError(
#     318         f"Input values for {self.name} class must be finite doubles"
#     319     )
#
# TypeError: Input values for mjd class must be finite doubles
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 co_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_7m+tp_co21_mom0.fits"
#       2 co_data = DisplayData(co_file)
#       3 co_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_co_regionfile_aca_twoboxes.reg"
# ----> 4 co_data.plot_region(co_file, co_bar_regionfile, norm='linear', vmin=0.00003, vmax=300)
#
# Cell In[5], line 92, in DisplayData.plot_region(self, filepath, regionfile, norm, vmin, vmax)
#      88         if data is None:
#      89             print("None")
#      90
#      91         wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
# ---> 92         region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel. the 0 is for the FIRST region plotted
#      93         region2 = Regions.read(regionfile)[1].to_pixel(wcs) # the one corresponds to the SECOND region plotted
#      94         fig, ax = plt.subplots()
#      95         ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\rectangle.py:428, in RectangleSkyRegion.to_pixel(self, wcs)
#     425 def to_pixel(self, wcs):
#     426     # Convert regions sky angle (from RA axis) to photutils PA (from
#     427     # North) by subtracting 90 deg.
# --> 428     center, pix_width, pix_height, angle = sky_shape_to_pixel_svd(
#     429         self.center, wcs,
#     430         self.width.to_value(u.arcsec),
#     431         self.height.to_value(u.arcsec),
#     432         self.angle.to_value(u.radian) - np.pi / 2)
#     433     return RectanglePixelRegion(PixCoord(*center), pix_width, pix_height,
#     434                                 angle=angle,
#     435                                 meta=self.meta.copy(),
#     436                                 visual=self.visual.copy())
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\_utils\wcs_helpers.py:583, in sky_shape_to_pixel_svd(skycoord, wcs, width_arcsec, height_arcsec, sky_angle_rad)
#     530 def sky_shape_to_pixel_svd(skycoord, wcs, width_arcsec, height_arcsec,
#     531                            sky_angle_rad):
#     532     """
#     533     Convert a sky ellipse to a pixel ellipse using SVD.
#     534
#    (...)    581         degrees.
#     582     """
# --> 583     center, jacobian, _ = _sky_to_pixel_jacobian(skycoord, wcs)
#     585     # Build M_sky: columns are sky semi-axis vectors in tangent-plane
#     586     # coordinates (xi=East, eta=North). The width axis is at the given
#     587     # PA from North (toward East), so its tangent-plane components are
#     588     # (sin(PA), cos(PA)); the height axis is perpendicular, at PA+90.
#     589     # The local Jacobian already encodes the WCS parity, so no manual
#     590     # parity factor is applied here.
#     591     cos_pa = np.cos(sky_angle_rad)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\_utils\wcs_helpers.py:47, in _sky_to_pixel_jacobian(skycoord, wcs)
#      18 def _sky_to_pixel_jacobian(skycoord, wcs):
#      19     """
#      20     Set up common values for sky-to-pixel Jacobian-based conversions.
#      21
#    (...)     45         The sign of ``det(jacobian)`` (+1 or -1).
#      46     """
# ---> 47     x0, y0 = wcs.world_to_pixel(skycoord)
#      48     center = (float(x0), float(y0))
#      49     jacobian = compute_local_wcs_jacobian(skycoord, wcs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:408, in HighLevelWCSMixin.world_to_pixel(self, *world_objects)
#     406 def world_to_pixel(self, *world_objects):
#     407     values, masks = MaskedNDArray._get_data_and_masks(world_objects)
# --> 408     world_values = high_level_objects_to_values(
#     409         *values, low_level_wcs=self.low_level_wcs
#     410     )
#     412     # Finally we convert to pixel coordinates
#     413     pixel_values = self.low_level_wcs.world_to_pixel_values(*world_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:194, in high_level_objects_to_values(low_level_wcs, *world_objects)
#     167 """
#     168 Convert the input high level object to low level values.
#     169
#    (...)    191     exposes by default.
#     192 """
#     193 # Cache the classes and components since this may be expensive
# --> 194 serialized_classes = low_level_wcs.world_axis_object_classes
#     195 components = low_level_wcs.world_axis_object_components
#     197 # Deserialize world_axis_object_classes using the default order
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\fitswcs.py:384, in FITSWCSAPIMixin.world_axis_object_classes(self)
#     382 @property
#     383 def world_axis_object_classes(self):
# --> 384     return self._get_components_and_classes()[1]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\fitswcs.py:486, in FITSWCSAPIMixin._get_components_and_classes(self)
#     483 tscale = self.wcs.timesys.lower() or "utc"
#     485 if np.isnan(self.wcs.mjdavg):
# --> 486     obstime = Time(
#     487         self.wcs.mjdobs,
#     488         format="mjd",
#     489         scale=tscale,
#     490         location=earth_location,
#     491     )
#     492 else:
#     493     obstime = Time(
#     494         self.wcs.mjdavg,
#     495         format="mjd",
#     496         scale=tscale,
#     497         location=earth_location,
#     498     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\core.py:1991, in Time.__init__(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, location, copy)
#    1989         self._set_scale(scale)
#    1990 else:
# -> 1991     self._init_from_vals(
#    1992         val, val2, format, scale, copy, precision, in_subfmt, out_subfmt
#    1993     )
#    1994     self.SCALES = TIME_TYPES[self.scale]
#    1996 if self.location is not None and (
#    1997     self.location.size > 1 and self.location.shape != self.shape
#    1998 ):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\core.py:559, in TimeBase._init_from_vals(self, val, val2, format, scale, copy, precision, in_subfmt, out_subfmt)
#     556 mask = combine_masks([mask1, mask2])
#     558 # Parse / convert input values into internal jd1, jd2 based on format
# --> 559 self._time = self._get_time_fmt(
#     560     data1, data2, format, scale, precision, in_subfmt, out_subfmt, mask
#     561 )
#     562 self._format = self._time.name
#     564 # Hack from #9969 to allow passing the location value that has been
#     565 # collected by the TimeAstropyTime format class up to the Time level.
#     566 # TODO: find a nicer way.
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\time\core.py:643, in TimeBase._get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, mask)
#     638 except (ValueError, TypeError) as err:
#     639     # If ``format`` specified then there is only one possibility, so raise
#     640     # immediately and include the upstream exception message to make it
#     641     # easier for user to see what is wrong.
#     642     if len(formats) == 1:
# --> 643         raise ValueError(
#     644             f"Input values did not match the format class {format}:"
#     645             + os.linesep
#     646             + f"{err.__class__.__name__}: {err}"
#     647         ) from err
#     648     else:
#     649         problems[name] = err
#
# ValueError: Input values did not match the format class mjd:
# TypeError: Input values for mjd class must be finite doubles

# %% [markdown]
# ## F21 MIRI: JWST

# %%
mirif21_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_miri_lv3_f2100w_i2d_align.fits"
mirif21_data = DisplayData(mirif21_file)
mirif21_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_f21miri_regionfile_jwst_twoboxes_updated.reg"
mirif21_data.plot_region(mirif21_file, mirif21_bar_regionfile, 'asinh', None, None)

# %% [markdown]
# ## HI: Meerkat

# %%
h1m_file = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/NGC0253_HI_mosaic_cube_mom0.fits"
h1m_data = DisplayData(h1m_file)
h1m_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_H1_regionfile_meerkatradio.reg"
h1m_data.plot_region(h1m_file, h1m_bar_regionfile, 'log', vmin=0.03, vmax=300)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 h1m_file = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/NGC0253_HI_mosaic_cube_mom0.fits"
#       2 h1m_data = DisplayData(h1m_file)
#       3 h1m_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_H1_regionfile_meerkatradio.reg"
# ----> 4 h1m_data.plot_region(h1m_file, h1m_bar_regionfile, 'log', vmin=0.03, vmax=300)
#
# Cell In[5], line 92, in DisplayData.plot_region(self, filepath, regionfile, norm, vmin, vmax)
#      88         if data is None:
#      89             print("None")
#      90
#      91         wcs = WCS(header) #see https://astronomy.stackexchange.com/questions/51673/how-to-slice-wcs-in-a-fits-file
# ---> 92         region = Regions.read(regionfile)[0].to_pixel(wcs) # access region file via parsing & converting data from wcs to pixel. the 0 is for the FIRST region plotted
#      93         region2 = Regions.read(regionfile)[1].to_pixel(wcs) # the one corresponds to the SECOND region plotted
#      94         fig, ax = plt.subplots()
#      95         ax.imshow(data, cmap='gray', origin='lower', norm=self.norm, vmin=self.vmin, vmax=self.vmax)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\rectangle.py:428, in RectangleSkyRegion.to_pixel(self, wcs)
#     425 def to_pixel(self, wcs):
#     426     # Convert regions sky angle (from RA axis) to photutils PA (from
#     427     # North) by subtracting 90 deg.
# --> 428     center, pix_width, pix_height, angle = sky_shape_to_pixel_svd(
#     429         self.center, wcs,
#     430         self.width.to_value(u.arcsec),
#     431         self.height.to_value(u.arcsec),
#     432         self.angle.to_value(u.radian) - np.pi / 2)
#     433     return RectanglePixelRegion(PixCoord(*center), pix_width, pix_height,
#     434                                 angle=angle,
#     435                                 meta=self.meta.copy(),
#     436                                 visual=self.visual.copy())
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\_utils\wcs_helpers.py:583, in sky_shape_to_pixel_svd(skycoord, wcs, width_arcsec, height_arcsec, sky_angle_rad)
#     530 def sky_shape_to_pixel_svd(skycoord, wcs, width_arcsec, height_arcsec,
#     531                            sky_angle_rad):
#     532     """
#     533     Convert a sky ellipse to a pixel ellipse using SVD.
#     534
#    (...)    581         degrees.
#     582     """
# --> 583     center, jacobian, _ = _sky_to_pixel_jacobian(skycoord, wcs)
#     585     # Build M_sky: columns are sky semi-axis vectors in tangent-plane
#     586     # coordinates (xi=East, eta=North). The width axis is at the given
#     587     # PA from North (toward East), so its tangent-plane components are
#     588     # (sin(PA), cos(PA)); the height axis is perpendicular, at PA+90.
#     589     # The local Jacobian already encodes the WCS parity, so no manual
#     590     # parity factor is applied here.
#     591     cos_pa = np.cos(sky_angle_rad)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\_utils\wcs_helpers.py:47, in _sky_to_pixel_jacobian(skycoord, wcs)
#      18 def _sky_to_pixel_jacobian(skycoord, wcs):
#      19     """
#      20     Set up common values for sky-to-pixel Jacobian-based conversions.
#      21
#    (...)     45         The sign of ``det(jacobian)`` (+1 or -1).
#      46     """
# ---> 47     x0, y0 = wcs.world_to_pixel(skycoord)
#      48     center = (float(x0), float(y0))
#      49     jacobian = compute_local_wcs_jacobian(skycoord, wcs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:408, in HighLevelWCSMixin.world_to_pixel(self, *world_objects)
#     406 def world_to_pixel(self, *world_objects):
#     407     values, masks = MaskedNDArray._get_data_and_masks(world_objects)
# --> 408     world_values = high_level_objects_to_values(
#     409         *values, low_level_wcs=self.low_level_wcs
#     410     )
#     412     # Finally we convert to pixel coordinates
#     413     pixel_values = self.low_level_wcs.world_to_pixel_values(*world_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:207, in high_level_objects_to_values(low_level_wcs, *world_objects)
#     205 # Check that the number of classes matches the number of inputs
#     206 if len(world_objects) != len(classes):
# --> 207     raise ValueError(
#     208         f"Number of world inputs ({len(world_objects)}) does not match expected"
#     209         f" ({len(classes)})"
#     210     )
#     212 # Determine whether the classes are uniquely matched, that is we check
#     213 # whether there is only one of each class.
#     214 world_by_key = {}
#
# ValueError: Number of world inputs (1) does not match expected (2)

# %%
ha_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\NGC0253_Ha.fits"
ha_data = DisplayData(ha_file)
ha_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_ha_regionfile_muse_twoboxes.reg"
ha_data.plot_region(ha_file, ha_bar_regionfile, norm = 'log', vmin=30, vmax=30000)
# Out:
# Found data in extension: HA6562_FLUX
# Found data in extension: HA6562_FLUX
# C:\Users\Lamat\AppData\Local\Programs\Python\Python314\Lib\site-packages\regions\shapes\rectangle.py:219: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Rectangle(xy=xy, width=width, height=height,

# %% [markdown]
# ## IRAC1: Spitzer

# %%
irac1_file= r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/ngc0253_lvl_release_irac1_gauss3.fits"
irac1_data = DisplayData(irac1_file)
irac1_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_irac1_regionfile_spitzer.reg"
irac1_data.plot_region(irac1_file, irac1_bar_regionfile, norm='log', vmin=0.005, vmax=255)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY

# %% [markdown]
# ## IRAC4: Spitzer

# %%
irac4_file = r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_irac4_gauss4p0.fits"
irac4_data = DisplayData(irac4_file)
irac4_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_irac4_regionfile_spitzer_twoboxes.reg"
irac4_data.plot_region(irac4_file, irac4_bar_regionfile, 'asinh', None, None)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY

# %% [markdown]
# ## W1: Spitzer

# %%
w1_file= r"C:\Users\Lamat\OneDrive - The Ohio State University\Lamat NGC 253 Environment Mask\Plotting Regions\ngc0253_w1_bgsub.fits"
w1_data = DisplayData(w1_file)
w1_bar_regionfile = r"C:\Users\Lamat\OneDrive - The Ohio State University/Lamat NGC 253 Environment Mask/Plotting Regions/bar_w1_regionfile_wise_twoboxes.reg"
w1_data.plot_region(w1_file, w1_bar_regionfile, norm='log', vmin=0.005, vmax=255)
# Out:
# Found data in extension: PRIMARY
# Found data in extension: PRIMARY
